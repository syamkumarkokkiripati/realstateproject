# %%
geospatial.data <- read.csv("E:\\geospatial.csv",header = TRUE,
                            stringsAsFactors = FALSE,
                            strip.white = TRUE,
                            sep = ",",
                            na.strings = c("","NA"))
str(geospatial.data)
# Out:
# 'data.frame':	236343 obs. of  12 variables:
#  $ track_record_id             : chr  "59231753" "59231858" "59231969" "59232069" ...
#  $ status_code                 : chr  "61441" "61441" "61441" "61441" ...
#  $ latitude_gps                : chr  "0" "0" "0" "0" ...
#  $ longitude_gps               : chr  "0" "0" "0" "0" ...
#  $ device_id_x                 : chr  "1001020218" "1001020218" "1001020218" "1001020218" ...
#  $ device_time_stamp           : chr  "12/13/2017 0:00" "12/13/2017 0:01" "12/13/2017 0:02" "12/13/2017 0:03" ...
#  $ asset_type                  : chr  "4111" "4111" "4111" "4111" ...
#  $ packet_generating_station_id: chr  "4.11E+11" "4.11E+11" "4.11E+11" "4.11E+11" ...
#  $ track_num1                  : chr  "0" "0" "0" "0" ...
#  $ asset_id_project            : chr  "MPV/27" "MPV/27" "MPV/27" "MPV/27" ...
#  $ project_id                  : chr  "2" "2" "2" "2" ...
#  $ supportsite_id              : chr  "2" "2" "2" "2" ...

# %%
library(Amelia)
missmap(geospatial.data, main = "Missing values vs observed")
# Out:
# Warning message:
# "package 'Amelia' was built under R version 3.5.2"Loading required package: Rcpp
# Warning message:
# "package 'Rcpp' was built under R version 3.5.2"##
# ## Amelia II: Multiple Imputation
# ## (Version 1.7.5, built: 2018-05-07)
# ## Copyright (C) 2005-2019 James Honaker, Gary King and Matthew Blackwell
# ## Refer to http://gking.harvard.edu/amelia/ for more information
# ##
# Plot with title "Missing values vs observed"

# %%
library(dplyr)
mspatial<-filter(geospatial.data,status_code==61445)
mspatial
# Out:
# Warning message:
# "package 'dplyr' was built under R version 3.5.2"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
# Warning message:
# "package 'bindrcpp' was built under R version 3.5.2"
#        track_record_id status_code latitude_gps longitude_gps device_id_x
# 1      59296503        61445       28.09939957  77.36451721   1001020218
# 2      59302213        61445       28.09976006  77.36509705   1001020218
# 3      59302768        61445       28.09971046  77.36506653   1001020218
# 4      59303102        61445       28.09972     77.36505127   1001020218
# 5      59303664        61445       28.09980965  77.36502838   1001020218
# 6      59303885        61445       28.09979057  77.36489105   1001020218
# 7      59304775        61445       28.09973907  77.36495209   1001020218
# ...

# %%
mspatial1<-filter(mspatial,track_num1==1)
mspatial1
# Out:
#       track_record_id status_code latitude_gps longitude_gps device_id_x
